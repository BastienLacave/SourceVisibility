# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# # LHAASO

# %%
output_path = f"/home/users/l/lacave/PhD/Analysis/SourceSensitivity/LHAASOVisibility/"
json_file_name = "/home/users/l/lacave/PhD/Analysis/SourceSensitivitySST1M/catalog/LHAASO_SST1M.json"
for i in range(1, 12, 1):
    start_date = f"'2024-{i:02d}-01 12:00'"
    end_date = f"'2024-{i+1:02d}-01 12:00'"

    # !digicamscheduling-elevation --start_date=$start_date --end_date=$end_date --time_step 15 --output_path $output_path --location_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/location_ondrejov.txt --sources_filename $json_file_name --use_moon --environment_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/environmental_limitation_ondrejov.txt
start_date = "'2024-12-01 12:00'"
end_date = "'2025-01-01 12:00'"
# !digicamscheduling-elevation --start_date=$start_date --end_date=$end_date --time_step 15 --output_path $output_path --location_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/location_ondrejov.txt --sources_filename $json_file_name --use_moon --environment_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/environmental_limitation_ondrejov.txt

# %% [markdown]
# Per day

# %%
output_path = f"/home/users/l/lacave/PhD/Analysis/SourceSensitivity/LHAASOVisibility/"
json_file_name = "/home/users/l/lacave/PhD/Analysis/SourceSensitivitySST1M/catalog/LHAASO_SST1M.json"
month = 6
last=31
for i in range(1, last, 1):
    start_date = f"'2024-{month:02d}-{i:02d} 12:00'"
    end_date = f"'2024-{month:02d}-{i+1:02d} 12:00'"

    # !digicamscheduling-elevation --start_date=$start_date --end_date=$end_date --time_step 15 --output_path $output_path --location_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/location_ondrejov.txt --sources_filename $json_file_name --use_moon --environment_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/environmental_limitation_ondrejov.txt
start_date = f"'2024-{month:02d}-{last} 12:00'"
end_date = f"'2024-{month+1:02d}-01 12:00'"
# !digicamscheduling-elevation --start_date=$start_date --end_date=$end_date --time_step 15 --output_path $output_path --location_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/location_ondrejov.txt --sources_filename $json_file_name --use_moon --environment_filename /home/users/l/lacave/PhD/digicamscheduling/digicamscheduling/config/digicamextra/environmental_limitation_ondrejov.txt
# Out:
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:01<00:34,  1.50s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:01<00:19,  1.12it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:02<00:15,  1.38it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:13,  1.53it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:03<00:12,  1.56it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:04<00:10,  1.65it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:04<00:09,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:05<00:09,  1.77it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:05<00:08,  1.77it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:06<00:07,  1.78it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:06<00:07,  1.74it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:07<00:06,  1.75it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:08<00:06,  1.75it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:08<00:06,  1.65it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:09<00:05,  1.67it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:09<00:04,  1.69it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:10<00:04,  1.68it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:11<00:03,  1.68it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:11<00:02,  1.72it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:12<00:02,  1.72it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:12<00:01,  1.71it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:13<00:01,  1.72it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:14<00:00,  1.74it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:14<00:00,  1.64it/s]
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:01<00:41,  1.80s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:02<00:23,  1.06s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:02<00:17,  1.17it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:15,  1.32it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:04<00:14,  1.34it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:04<00:12,  1.43it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:05<00:11,  1.47it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:06<00:10,  1.52it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:06<00:09,  1.57it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:07<00:08,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:07<00:08,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:08<00:07,  1.62it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:09<00:06,  1.65it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:09<00:06,  1.56it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:10<00:05,  1.59it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:11<00:04,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:11<00:04,  1.65it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:12<00:03,  1.67it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:12<00:02,  1.69it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:13<00:02,  1.67it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:14<00:01,  1.66it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:14<00:01,  1.66it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:15<00:00,  1.68it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:15<00:00,  1.51it/s]
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:01<00:44,  1.93s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:02<00:25,  1.15s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:03<00:18,  1.12it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:15,  1.29it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:04<00:14,  1.34it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:05<00:12,  1.43it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:05<00:11,  1.49it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:06<00:10,  1.54it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:06<00:09,  1.58it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:07<00:08,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:08<00:08,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:08<00:07,  1.63it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:09<00:06,  1.64it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:09<00:06,  1.56it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:10<00:05,  1.57it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:11<00:05,  1.60it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:11<00:04,  1.62it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:12<00:03,  1.64it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:12<00:02,  1.71it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:13<00:02,  1.79it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:13<00:01,  1.84it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:14<00:01,  1.88it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:14<00:00,  1.90it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:15<00:00,  1.54it/s]
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:01<00:41,  1.81s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:02<00:24,  1.10s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:03<00:18,  1.15it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:15,  1.30it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:04<00:14,  1.35it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:04<00:12,  1.45it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:05<00:11,  1.51it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:06<00:10,  1.57it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:06<00:09,  1.62it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:07<00:08,  1.65it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:07<00:07,  1.67it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:08<00:06,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:08<00:06,  1.83it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:09<00:05,  1.78it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:09<00:04,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:10<00:04,  1.91it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:10<00:03,  1.97it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:11<00:03,  1.98it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:11<00:02,  1.96it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:12<00:02,  1.91it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:13<00:01,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:13<00:01,  1.85it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:14<00:00,  1.85it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:14<00:00,  1.62it/s]
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:01<00:41,  1.79s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:02<00:23,  1.09s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:02<00:18,  1.16it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:15,  1.32it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:04<00:14,  1.36it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:04<00:12,  1.44it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:05<00:10,  1.56it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:05<00:09,  1.67it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:06<00:08,  1.75it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:06<00:07,  1.83it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:07<00:06,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:07<00:06,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:08<00:06,  1.80it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:09<00:05,  1.68it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:09<00:05,  1.72it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:10<00:04,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:10<00:04,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:11<00:03,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
# ...
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:06<00:06,  2.16it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:06<00:05,  2.22it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:06<00:05,  2.23it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:07<00:05,  2.13it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:07<00:04,  2.08it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:08<00:04,  1.94it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:08<00:03,  2.02it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:09<00:03,  2.05it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:09<00:02,  2.07it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:10<00:02,  2.10it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:10<00:01,  2.13it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:11<00:01,  2.14it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:11<00:00,  2.10it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:12<00:00,  2.07it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:12<00:00,  1.88it/s]
# Source:   0%|                                            | 0/24 [00:00<?, ?it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   4%|█▌                                  | 1/24 [00:02<00:51,  2.25s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:   8%|███                                 | 2/24 [00:02<00:25,  1.17s/it]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  12%|████▌                               | 3/24 [00:03<00:17,  1.18it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  17%|██████                              | 4/24 [00:03<00:13,  1.47it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  21%|███████▌                            | 5/24 [00:04<00:11,  1.61it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  25%|█████████                           | 6/24 [00:04<00:10,  1.73it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  29%|██████████▌                         | 7/24 [00:05<00:09,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  33%|████████████                        | 8/24 [00:05<00:08,  1.94it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  38%|█████████████▌                      | 9/24 [00:05<00:07,  1.93it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  42%|██████████████▌                    | 10/24 [00:06<00:07,  1.87it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  46%|████████████████                   | 11/24 [00:07<00:06,  1.96it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  50%|█████████████████▌                 | 12/24 [00:07<00:05,  2.02it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  54%|██████████████████▉                | 13/24 [00:08<00:05,  1.84it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  58%|████████████████████▍              | 14/24 [00:08<00:05,  1.94it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  62%|█████████████████████▉             | 15/24 [00:09<00:04,  1.90it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  67%|███████████████████████▎           | 16/24 [00:09<00:04,  1.84it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  71%|████████████████████████▊          | 17/24 [00:10<00:03,  1.82it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  75%|██████████████████████████▎        | 18/24 [00:10<00:03,  1.78it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  79%|███████████████████████████▋       | 19/24 [00:11<00:02,  1.80it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  83%|█████████████████████████████▏     | 20/24 [00:11<00:02,  1.80it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  88%|██████████████████████████████▋    | 21/24 [00:12<00:01,  1.81it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  92%|████████████████████████████████   | 22/24 [00:13<00:01,  1.86it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source:  96%|█████████████████████████████████▌ | 23/24 [00:13<00:00,  1.92it/s]/home/users/l/lacave/mambaforge/envs/sst1m-dev/lib/python3.8/site-packages/digicamscheduling/display/plot.py:53: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   axes.plot_date(date.plot_date, y, **kwargs)
# Figure(1200x400)
# Source: 100%|███████████████████████████████████| 24/24 [00:13<00:00,  1.71it/s]
